# %% [markdown]
# # Import libraries

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Test on one dataset

# %% [markdown]
# ## Our Dataset

# %%
# Load waypoints
file_name = "IL_C_A_RCCW_1"
# output_dir = f"/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Straight Line/Diagonal Line/{file_name}"
output_dir = f"/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Infinity Loop/{file_name}"

data_path = os.path.join(output_dir, "pose_waypoints_sampled_2.5hz_raw.csv") # A 10hz dataset
data_path_2 = os.path.join(output_dir, "pose_waypoints_sampled_2.5hz_clean.csv") # A 2.5hz dataset


# Set parameters
plot_2 = False # To plot the 2.5hz dataset on the same graph
avg_window_lin = 8 # The number of steps to average the linear velocity
avg_window_ang = 8 # The number of steps to average the angular velocity
pred_model = 'CTRV' # The prediction model to be used

# %%
# Parse ground truth data
ground_truth = []
ground_truth_2 = []

def parse_value(val):
    if val is None:
        return np.nan
    val = val.strip().lower()
    return float(val) if val not in ('', 'none', 'nan') else np.nan


# Read the CSV file with a header
with open(data_path, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ground_truth.append([
            float(row["timestamp"]),
            float(row["ped_id"]),
            parse_value(row["x"]),
            parse_value(row["y"])
            ])

# Read the CSV file with a header
with open(data_path_2, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ground_truth_2.append([
            float(row["timestamp"]),
            float(row["ped_id"]),
            parse_value(row["x"]),
            parse_value(row["y"])
            ])
        
gt_array = np.array(ground_truth)
gt_array_2 = np.array(ground_truth_2)

print("Ground truth data loaded with the length: ", len(ground_truth))
# Out:
# Ground truth data loaded with the length:  23

# %% [markdown]
# ## ETH Dataset

# %%
# Load waypoints
file_name = "ETH_datasets"
output_dir = f"/home/sina/env_prediction_project/motion_predictor/{file_name}"

data_path = os.path.join(output_dir, "biwi_hotel.csv") # A 10hz dataset
data_path_2 = os.path.join(output_dir, "pose_waypoints_sampled_2.5hz_clean.csv") # A 2.5hz dataset

# Set parameters
plot_2 = False # To plot the 2.5hz dataset on the same graph
avg_window_lin = 8 # The number of steps to average the linear velocity
avg_window_ang = 8 # The number of steps to average the angular velocity
pred_model = 'CTRV' # The prediction model to be used

# %%
# Load waypoints and separate all
file_name = "ETH_datasets"
output_dir = f"/home/sina/env_prediction_project/motion_predictor/{file_name}"
data_path = os.path.join(output_dir, "students003.csv")  # A 10Hz dataset

# Create a dictionary to hold data for each ped_id
pedestrian_data = {}

# Read the CSV file with a header
with open(data_path, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ped_id = int(float(row["ped_id"]))  # Convert to int for cleaner filenames
        entry = [int(float(row["timestamp"])), ped_id, float(row["x"]), float(row["y"])]

        if ped_id not in pedestrian_data:
            pedestrian_data[ped_id] = []
        pedestrian_data[ped_id].append(entry)
        
# Write each ped_id's data into a separate CSV file
for ped_id, data in pedestrian_data.items():
    output_subdir = os.path.join(output_dir, f"U3_C_A_DIR_{ped_id}")
    os.makedirs(output_subdir, exist_ok=True)

    output_file = os.path.join(output_subdir, f"ped_path_clean.csv")
    with open(output_file, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["timestamp", "ped_id", "x", "y"])  # Write header
        writer.writerows(data)

    print(f"Saved {len(data)} entries for ped_id {ped_id} to {output_file}")
# Out:
# Saved 16 entries for ped_id 1 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_1/ped_path_clean.csv
# Saved 10 entries for ped_id 2 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_2/ped_path_clean.csv
# Saved 38 entries for ped_id 3 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_3/ped_path_clean.csv
# Saved 108 entries for ped_id 4 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_4/ped_path_clean.csv
# Saved 28 entries for ped_id 5 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_5/ped_path_clean.csv
# Saved 11 entries for ped_id 6 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_6/ped_path_clean.csv
# Saved 45 entries for ped_id 7 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_7/ped_path_clean.csv
# Saved 47 entries for ped_id 8 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_8/ped_path_clean.csv
# Saved 30 entries for ped_id 9 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_9/ped_path_clean.csv
# Saved 64 entries for ped_id 10 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_10/ped_path_clean.csv
# Saved 64 entries for ped_id 11 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_11/ped_path_clean.csv
# Saved 61 entries for ped_id 12 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_12/ped_path_clean.csv
# Saved 65 entries for ped_id 13 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_13/ped_path_clean.csv
# Saved 31 entries for ped_id 14 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_14/ped_path_clean.csv
# Saved 27 entries for ped_id 15 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_15/ped_path_clean.csv
# Saved 31 entries for ped_id 16 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_16/ped_path_clean.csv
# Saved 22 entries for ped_id 21 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_21/ped_path_clean.csv
# Saved 23 entries for ped_id 22 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_22/ped_path_clean.csv
# Saved 40 entries for ped_id 25 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_25/ped_path_clean.csv
# Saved 12 entries for ped_id 213 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_213/ped_path_clean.csv
# Saved 14 entries for ped_id 214 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_214/ped_path_clean.csv
# Saved 18 entries for ped_id 215 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_215/ped_path_clean.csv
# Saved 18 entries for ped_id 216 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_216/ped_path_clean.csv
# Saved 83 entries for ped_id 217 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_217/ped_path_clean.csv
# Saved 16 entries for ped_id 218 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_218/ped_path_clean.csv
# Saved 83 entries for ped_id 219 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_219/ped_path_clean.csv
# Saved 83 entries for ped_id 220 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_220/ped_path_clean.csv
# Saved 25 entries for ped_id 273 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_273/ped_path_clean.csv
# Saved 24 entries for ped_id 409 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_409/ped_path_clean.csv
# Saved 50 entries for ped_id 23 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_23/ped_path_clean.csv
# Saved 33 entries for ped_id 17 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_17/ped_path_clean.csv
# Saved 15 entries for ped_id 18 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_18/ped_path_clean.csv
# Saved 27 entries for ped_id 24 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_24/ped_path_clean.csv
# Saved 51 entries for ped_id 19 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_19/ped_path_clean.csv
# Saved 63 entries for ped_id 74 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_74/ped_path_clean.csv
# Saved 103 entries for ped_id 75 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_75/ped_path_clean.csv
# Saved 63 entries for ped_id 76 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_76/ped_path_clean.csv
# Saved 16 entries for ped_id 274 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_274/ped_path_clean.csv
# Saved 45 entries for ped_id 20 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_20/ped_path_clean.csv
# Saved 36 entries for ped_id 26 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_26/ped_path_clean.csv
# Saved 63 entries for ped_id 28 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_28/ped_path_clean.csv
# Saved 42 entries for ped_id 27 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_27/ped_path_clean.csv
# Saved 41 entries for ped_id 29 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_29/ped_path_clean.csv
# Saved 59 entries for ped_id 30 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_30/ped_path_clean.csv
# Saved 51 entries for ped_id 77 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_77/ped_path_clean.csv
# Saved 49 entries for ped_id 78 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_78/ped_path_clean.csv
# Saved 19 entries for ped_id 31 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_31/ped_path_clean.csv
# Saved 24 entries for ped_id 73 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_73/ped_path_clean.csv
# Saved 25 entries for ped_id 419 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_419/ped_path_clean.csv
# Saved 29 entries for ped_id 420 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_420/ped_path_clean.csv
# Saved 17 entries for ped_id 32 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_32/ped_path_clean.csv
# Saved 35 entries for ped_id 79 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_79/ped_path_clean.csv
# Saved 31 entries for ped_id 315 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_315/ped_path_clean.csv
# Saved 51 entries for ped_id 80 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_80/ped_path_clean.csv
# Saved 50 entries for ped_id 82 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_82/ped_path_clean.csv
# Saved 43 entries for ped_id 81 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_81/ped_path_clean.csv
# Saved 38 entries for ped_id 33 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_33/ped_path_clean.csv
# Saved 33 entries for ped_id 34 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_34/ped_path_clean.csv
# Saved 21 entries for ped_id 35 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_35/ped_path_clean.csv
# Saved 53 entries for ped_id 37 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_37/ped_path_clean.csv
# Saved 19 entries for ped_id 36 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_36/ped_path_clean.csv
# Saved 50 entries for ped_id 410 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_410/ped_path_clean.csv
# Saved 68 entries for ped_id 83 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_83/ped_path_clean.csv
# Saved 53 entries for ped_id 411 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_411/ped_path_clean.csv
# Saved 33 entries for ped_id 84 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_84/ped_path_clean.csv
# Saved 34 entries for ped_id 85 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_85/ped_path_clean.csv
# Saved 63 entries for ped_id 316 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_316/ped_path_clean.csv
# Saved 61 entries for ped_id 317 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_317/ped_path_clean.csv
# Saved 69 entries for ped_id 300 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_300/ped_path_clean.csv
# Saved 7 entries for ped_id 305 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_305/ped_path_clean.csv
# Saved 43 entries for ped_id 86 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_86/ped_path_clean.csv
# Saved 61 entries for ped_id 301 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_301/ped_path_clean.csv
# Saved 48 entries for ped_id 38 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_38/ped_path_clean.csv
# Saved 46 entries for ped_id 39 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_39/ped_path_clean.csv
# Saved 34 entries for ped_id 302 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_302/ped_path_clean.csv
# Saved 19 entries for ped_id 40 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_40/ped_path_clean.csv
# Saved 40 entries for ped_id 41 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_41/ped_path_clean.csv
# Saved 61 entries for ped_id 221 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_221/ped_path_clean.csv
# Saved 289 entries for ped_id 232 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_232/ped_path_clean.csv
# Saved 288 entries for ped_id 233 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_233/ped_path_clean.csv
# Saved 19 entries for ped_id 303 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_303/ped_path_clean.csv
# Saved 18 entries for ped_id 304 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_304/ped_path_clean.csv
# Saved 37 entries for ped_id 42 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_42/ped_path_clean.csv
# Saved 31 entries for ped_id 43 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_43/ped_path_clean.csv
# Saved 132 entries for ped_id 222 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_222/ped_path_clean.csv
# Saved 37 entries for ped_id 44 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_44/ped_path_clean.csv
# Saved 71 entries for ped_id 45 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_45/ped_path_clean.csv
# Saved 61 entries for ped_id 87 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_87/ped_path_clean.csv
# Saved 53 entries for ped_id 223 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_223/ped_path_clean.csv
# Saved 69 entries for ped_id 46 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_46/ped_path_clean.csv
# Saved 70 entries for ped_id 47 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_47/ped_path_clean.csv
# Saved 35 entries for ped_id 235 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_235/ped_path_clean.csv
# Saved 43 entries for ped_id 224 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_224/ped_path_clean.csv
# Saved 19 entries for ped_id 275 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_275/ped_path_clean.csv
# Saved 29 entries for ped_id 88 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_88/ped_path_clean.csv
# Saved 27 entries for ped_id 234 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_234/ped_path_clean.csv
# Saved 42 entries for ped_id 226 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_226/ped_path_clean.csv
# Saved 11 entries for ped_id 306 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_306/ped_path_clean.csv
# Saved 46 entries for ped_id 48 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_48/ped_path_clean.csv
# Saved 46 entries for ped_id 49 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_49/ped_path_clean.csv
# Saved 66 entries for ped_id 225 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_225/ped_path_clean.csv
# Saved 35 entries for ped_id 312 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_312/ped_path_clean.csv
# Saved 9 entries for ped_id 307 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_307/ped_path_clean.csv
# Saved 116 entries for ped_id 340 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_340/ped_path_clean.csv
# Saved 48 entries for ped_id 89 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_89/ped_path_clean.csv
# Saved 49 entries for ped_id 90 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_90/ped_path_clean.csv
# Saved 39 entries for ped_id 91 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_91/ped_path_clean.csv
# Saved 30 entries for ped_id 227 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_227/ped_path_clean.csv
# Saved 45 entries for ped_id 228 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_228/ped_path_clean.csv
# Saved 54 entries for ped_id 50 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_50/ped_path_clean.csv
# Saved 95 entries for ped_id 51 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_51/ped_path_clean.csv
# Saved 41 entries for ped_id 92 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_92/ped_path_clean.csv
# Saved 24 entries for ped_id 308 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_308/ped_path_clean.csv
# Saved 21 entries for ped_id 309 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_309/ped_path_clean.csv
# Saved 27 entries for ped_id 318 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_318/ped_path_clean.csv
# Saved 27 entries for ped_id 319 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_319/ped_path_clean.csv
# Saved 48 entries for ped_id 93 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_93/ped_path_clean.csv
# Saved 35 entries for ped_id 230 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_230/ped_path_clean.csv
# Saved 45 entries for ped_id 229 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_229/ped_path_clean.csv
# Saved 38 entries for ped_id 341 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_341/ped_path_clean.csv
# Saved 37 entries for ped_id 94 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_94/ped_path_clean.csv
# Saved 39 entries for ped_id 95 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_95/ped_path_clean.csv
# Saved 46 entries for ped_id 52 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_52/ped_path_clean.csv
# Saved 16 entries for ped_id 310 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_310/ped_path_clean.csv
# Saved 43 entries for ped_id 53 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_53/ped_path_clean.csv
# Saved 25 entries for ped_id 311 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_311/ped_path_clean.csv
# Saved 48 entries for ped_id 96 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_96/ped_path_clean.csv
# Saved 40 entries for ped_id 54 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_54/ped_path_clean.csv
# Saved 65 entries for ped_id 55 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_55/ped_path_clean.csv
# Saved 65 entries for ped_id 56 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_56/ped_path_clean.csv
# Saved 41 entries for ped_id 231 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_231/ped_path_clean.csv
# Saved 29 entries for ped_id 313 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_313/ped_path_clean.csv
# Saved 15 entries for ped_id 342 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_342/ped_path_clean.csv
# Saved 230 entries for ped_id 376 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_376/ped_path_clean.csv
# Saved 20 entries for ped_id 344 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_344/ped_path_clean.csv
# Saved 40 entries for ped_id 57 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_57/ped_path_clean.csv
# Saved 65 entries for ped_id 343 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_343/ped_path_clean.csv
# Saved 26 entries for ped_id 97 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_97/ped_path_clean.csv
# Saved 57 entries for ped_id 98 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_98/ped_path_clean.csv
# Saved 59 entries for ped_id 99 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_99/ped_path_clean.csv
# Saved 30 entries for ped_id 100 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_100/ped_path_clean.csv
# Saved 26 entries for ped_id 101 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_101/ped_path_clean.csv
# Saved 47 entries for ped_id 58 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_58/ped_path_clean.csv
# Saved 45 entries for ped_id 59 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_59/ped_path_clean.csv
# Saved 37 entries for ped_id 60 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_60/ped_path_clean.csv
# Saved 36 entries for ped_id 61 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_61/ped_path_clean.csv
# Saved 30 entries for ped_id 102 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_102/ped_path_clean.csv
# Saved 97 entries for ped_id 72 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_72/ped_path_clean.csv
# Saved 30 entries for ped_id 412 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_412/ped_path_clean.csv
# Saved 31 entries for ped_id 413 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_413/ped_path_clean.csv
# Saved 27 entries for ped_id 414 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_414/ped_path_clean.csv
# Saved 36 entries for ped_id 62 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_62/ped_path_clean.csv
# Saved 37 entries for ped_id 63 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_63/ped_path_clean.csv
# Saved 55 entries for ped_id 345 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_345/ped_path_clean.csv
# Saved 56 entries for ped_id 346 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_346/ped_path_clean.csv
# Saved 42 entries for ped_id 347 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_347/ped_path_clean.csv
# Saved 70 entries for ped_id 64 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_64/ped_path_clean.csv
# Saved 67 entries for ped_id 66 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_66/ped_path_clean.csv
# Saved 89 entries for ped_id 103 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_103/ped_path_clean.csv
# Saved 67 entries for ped_id 65 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_65/ped_path_clean.csv
# Saved 18 entries for ped_id 348 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_348/ped_path_clean.csv
# Saved 56 entries for ped_id 104 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_104/ped_path_clean.csv
# Saved 18 entries for ped_id 349 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_349/ped_path_clean.csv
# Saved 48 entries for ped_id 421 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_421/ped_path_clean.csv
# Saved 44 entries for ped_id 422 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_422/ped_path_clean.csv
# Saved 44 entries for ped_id 67 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_67/ped_path_clean.csv
# Saved 55 entries for ped_id 237 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_237/ped_path_clean.csv
# Saved 42 entries for ped_id 423 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_423/ped_path_clean.csv
# Saved 28 entries for ped_id 68 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_68/ped_path_clean.csv
# Saved 25 entries for ped_id 69 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_69/ped_path_clean.csv
# Saved 44 entries for ped_id 236 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_236/ped_path_clean.csv
# Saved 22 entries for ped_id 424 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_424/ped_path_clean.csv
# Saved 42 entries for ped_id 425 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_425/ped_path_clean.csv
# Saved 38 entries for ped_id 426 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_426/ped_path_clean.csv
# Saved 48 entries for ped_id 70 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_70/ped_path_clean.csv
# Saved 48 entries for ped_id 71 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_71/ped_path_clean.csv
# Saved 25 entries for ped_id 105 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_105/ped_path_clean.csv
# Saved 31 entries for ped_id 320 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_320/ped_path_clean.csv
# Saved 45 entries for ped_id 106 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_106/ped_path_clean.csv
# Saved 45 entries for ped_id 107 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_107/ped_path_clean.csv
# Saved 178 entries for ped_id 238 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_238/ped_path_clean.csv
# Saved 21 entries for ped_id 314 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_314/ped_path_clean.csv
# Saved 48 entries for ped_id 109 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_109/ped_path_clean.csv
# Saved 46 entries for ped_id 108 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_108/ped_path_clean.csv
# Saved 24 entries for ped_id 239 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_239/ped_path_clean.csv
# Saved 21 entries for ped_id 240 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_240/ped_path_clean.csv
# Saved 21 entries for ped_id 241 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_241/ped_path_clean.csv
# Saved 51 entries for ped_id 110 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_110/ped_path_clean.csv
# Saved 9 entries for ped_id 276 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_276/ped_path_clean.csv
# Saved 40 entries for ped_id 111 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_111/ped_path_clean.csv
# Saved 38 entries for ped_id 112 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_112/ped_path_clean.csv
# Saved 25 entries for ped_id 350 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_350/ped_path_clean.csv
# Saved 23 entries for ped_id 351 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_351/ped_path_clean.csv
# Saved 31 entries for ped_id 242 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_242/ped_path_clean.csv
# Saved 25 entries for ped_id 352 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_352/ped_path_clean.csv
# Saved 20 entries for ped_id 353 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_353/ped_path_clean.csv
# Saved 31 entries for ped_id 113 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_113/ped_path_clean.csv
# Saved 65 entries for ped_id 243 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_243/ped_path_clean.csv
# Saved 54 entries for ped_id 114 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_114/ped_path_clean.csv
# Saved 58 entries for ped_id 115 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_115/ped_path_clean.csv
# Saved 58 entries for ped_id 116 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_116/ped_path_clean.csv
# Saved 71 entries for ped_id 244 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_244/ped_path_clean.csv
# Saved 72 entries for ped_id 245 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_245/ped_path_clean.csv
# Saved 70 entries for ped_id 321 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_321/ped_path_clean.csv
# Saved 51 entries for ped_id 117 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_117/ped_path_clean.csv
# Saved 10 entries for ped_id 427 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_427/ped_path_clean.csv
# Saved 13 entries for ped_id 428 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_428/ped_path_clean.csv
# Saved 13 entries for ped_id 429 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_429/ped_path_clean.csv
# Saved 25 entries for ped_id 118 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_118/ped_path_clean.csv
# Saved 25 entries for ped_id 119 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_119/ped_path_clean.csv
# Saved 21 entries for ped_id 378 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_378/ped_path_clean.csv
# Saved 22 entries for ped_id 379 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_379/ped_path_clean.csv
# Saved 33 entries for ped_id 377 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_377/ped_path_clean.csv
# Saved 40 entries for ped_id 246 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_246/ped_path_clean.csv
# Saved 38 entries for ped_id 247 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_247/ped_path_clean.csv
# Saved 29 entries for ped_id 120 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_120/ped_path_clean.csv
# Saved 68 entries for ped_id 121 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_121/ped_path_clean.csv
# Saved 56 entries for ped_id 322 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_322/ped_path_clean.csv
# Saved 47 entries for ped_id 323 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_323/ped_path_clean.csv
# Saved 48 entries for ped_id 122 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_122/ped_path_clean.csv
# Saved 66 entries for ped_id 123 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_123/ped_path_clean.csv
# Saved 44 entries for ped_id 124 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_124/ped_path_clean.csv
# Saved 30 entries for ped_id 125 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_125/ped_path_clean.csv
# Saved 31 entries for ped_id 126 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_126/ped_path_clean.csv
# Saved 58 entries for ped_id 127 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_127/ped_path_clean.csv
# Saved 62 entries for ped_id 128 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_128/ped_path_clean.csv
# Saved 148 entries for ped_id 248 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_248/ped_path_clean.csv
# Saved 61 entries for ped_id 129 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_129/ped_path_clean.csv
# Saved 60 entries for ped_id 130 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_130/ped_path_clean.csv
# Saved 39 entries for ped_id 131 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_131/ped_path_clean.csv
# Saved 62 entries for ped_id 132 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_132/ped_path_clean.csv
# Saved 144 entries for ped_id 249 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_249/ped_path_clean.csv
# Saved 22 entries for ped_id 380 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_380/ped_path_clean.csv
# Saved 24 entries for ped_id 381 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_381/ped_path_clean.csv
# Saved 59 entries for ped_id 133 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_133/ped_path_clean.csv
# Saved 89 entries for ped_id 324 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_324/ped_path_clean.csv
# Saved 50 entries for ped_id 134 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_134/ped_path_clean.csv
# Saved 22 entries for ped_id 250 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_250/ped_path_clean.csv
# Saved 37 entries for ped_id 251 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_251/ped_path_clean.csv
# Saved 35 entries for ped_id 135 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_135/ped_path_clean.csv
# Saved 42 entries for ped_id 252 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_252/ped_path_clean.csv
# Saved 23 entries for ped_id 382 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_382/ped_path_clean.csv
# Saved 24 entries for ped_id 383 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_383/ped_path_clean.csv
# Saved 20 entries for ped_id 384 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_384/ped_path_clean.csv
# Saved 86 entries for ped_id 325 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_325/ped_path_clean.csv
# Saved 35 entries for ped_id 136 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_136/ped_path_clean.csv
# Saved 6 entries for ped_id 385 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_385/ped_path_clean.csv
# Saved 48 entries for ped_id 137 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_137/ped_path_clean.csv
# Saved 48 entries for ped_id 138 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_138/ped_path_clean.csv
# Saved 36 entries for ped_id 386 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_386/ped_path_clean.csv
# Saved 26 entries for ped_id 139 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_139/ped_path_clean.csv
# Saved 53 entries for ped_id 253 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_253/ped_path_clean.csv
# Saved 54 entries for ped_id 254 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_254/ped_path_clean.csv
# Saved 45 entries for ped_id 140 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_140/ped_path_clean.csv
# Saved 26 entries for ped_id 255 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_255/ped_path_clean.csv
# Saved 44 entries for ped_id 141 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_141/ped_path_clean.csv
# Saved 49 entries for ped_id 326 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_326/ped_path_clean.csv
# Saved 48 entries for ped_id 327 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_327/ped_path_clean.csv
# Saved 182 entries for ped_id 142 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_142/ped_path_clean.csv
# Saved 137 entries for ped_id 256 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_256/ped_path_clean.csv
# Saved 26 entries for ped_id 257 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_257/ped_path_clean.csv
# Saved 34 entries for ped_id 258 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_258/ped_path_clean.csv
# Saved 39 entries for ped_id 143 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_143/ped_path_clean.csv
# Saved 32 entries for ped_id 144 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_144/ped_path_clean.csv
# Saved 38 entries for ped_id 277 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_277/ped_path_clean.csv
# Saved 42 entries for ped_id 145 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_145/ped_path_clean.csv
# Saved 97 entries for ped_id 259 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_259/ped_path_clean.csv
# Saved 48 entries for ped_id 328 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_328/ped_path_clean.csv
# Saved 44 entries for ped_id 146 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_146/ped_path_clean.csv
# Saved 61 entries for ped_id 354 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_354/ped_path_clean.csv
# Saved 46 entries for ped_id 147 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_147/ped_path_clean.csv
# Saved 59 entries for ped_id 355 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_355/ped_path_clean.csv
# Saved 18 entries for ped_id 356 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_356/ped_path_clean.csv
# Saved 19 entries for ped_id 357 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_357/ped_path_clean.csv
# Saved 32 entries for ped_id 148 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_148/ped_path_clean.csv
# Saved 32 entries for ped_id 149 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_149/ped_path_clean.csv
# Saved 20 entries for ped_id 387 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_387/ped_path_clean.csv
# Saved 20 entries for ped_id 388 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_388/ped_path_clean.csv
# Saved 23 entries for ped_id 389 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_389/ped_path_clean.csv
# Saved 15 entries for ped_id 390 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_390/ped_path_clean.csv
# Saved 41 entries for ped_id 391 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_391/ped_path_clean.csv
# Saved 34 entries for ped_id 392 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_392/ped_path_clean.csv
# Saved 40 entries for ped_id 150 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_150/ped_path_clean.csv
# Saved 38 entries for ped_id 151 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_151/ped_path_clean.csv
# Saved 78 entries for ped_id 329 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_329/ped_path_clean.csv
# Saved 35 entries for ped_id 152 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_152/ped_path_clean.csv
# Saved 33 entries for ped_id 153 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_153/ped_path_clean.csv
# Saved 42 entries for ped_id 330 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_330/ped_path_clean.csv
# Saved 32 entries for ped_id 154 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_154/ped_path_clean.csv
# Saved 75 entries for ped_id 331 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_331/ped_path_clean.csv
# Saved 44 entries for ped_id 260 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_260/ped_path_clean.csv
# Saved 65 entries for ped_id 155 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_155/ped_path_clean.csv
# Saved 69 entries for ped_id 332 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_332/ped_path_clean.csv
# Saved 58 entries for ped_id 156 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_156/ped_path_clean.csv
# Saved 21 entries for ped_id 157 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_157/ped_path_clean.csv
# Saved 26 entries for ped_id 261 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_261/ped_path_clean.csv
# Saved 32 entries for ped_id 393 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_393/ped_path_clean.csv
# Saved 21 entries for ped_id 394 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_394/ped_path_clean.csv
# Saved 28 entries for ped_id 395 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_395/ped_path_clean.csv
# Saved 24 entries for ped_id 415 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_415/ped_path_clean.csv
# Saved 25 entries for ped_id 416 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_416/ped_path_clean.csv
# Saved 56 entries for ped_id 158 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_158/ped_path_clean.csv
# Saved 37 entries for ped_id 159 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_159/ped_path_clean.csv
# Saved 35 entries for ped_id 396 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_396/ped_path_clean.csv
# Saved 59 entries for ped_id 160 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_160/ped_path_clean.csv
# Saved 31 entries for ped_id 161 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_161/ped_path_clean.csv
# Saved 31 entries for ped_id 162 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_162/ped_path_clean.csv
# Saved 31 entries for ped_id 163 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_163/ped_path_clean.csv
# Saved 40 entries for ped_id 358 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_358/ped_path_clean.csv
# Saved 22 entries for ped_id 359 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_359/ped_path_clean.csv
# Saved 65 entries for ped_id 334 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_334/ped_path_clean.csv
# Saved 32 entries for ped_id 164 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_164/ped_path_clean.csv
# Saved 16 entries for ped_id 397 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_397/ped_path_clean.csv
# Saved 49 entries for ped_id 165 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_165/ped_path_clean.csv
# Saved 44 entries for ped_id 166 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_166/ped_path_clean.csv
# Saved 26 entries for ped_id 262 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_262/ped_path_clean.csv
# Saved 42 entries for ped_id 167 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_167/ped_path_clean.csv
# Saved 48 entries for ped_id 168 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_168/ped_path_clean.csv
# Saved 52 entries for ped_id 333 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_333/ped_path_clean.csv
# Saved 49 entries for ped_id 335 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_335/ped_path_clean.csv
# Saved 26 entries for ped_id 278 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_278/ped_path_clean.csv
# Saved 23 entries for ped_id 279 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_279/ped_path_clean.csv
# Saved 19 entries for ped_id 280 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_280/ped_path_clean.csv
# Saved 50 entries for ped_id 360 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_360/ped_path_clean.csv
# Saved 70 entries for ped_id 169 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_169/ped_path_clean.csv
# Saved 40 entries for ped_id 282 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_282/ped_path_clean.csv
# Saved 49 entries for ped_id 361 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_361/ped_path_clean.csv
# Saved 15 entries for ped_id 281 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_281/ped_path_clean.csv
# Saved 13 entries for ped_id 398 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_398/ped_path_clean.csv
# Saved 28 entries for ped_id 399 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_399/ped_path_clean.csv
# Saved 38 entries for ped_id 336 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_336/ped_path_clean.csv
# Saved 28 entries for ped_id 170 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_170/ped_path_clean.csv
# Saved 25 entries for ped_id 285 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_285/ped_path_clean.csv
# Saved 23 entries for ped_id 283 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_283/ped_path_clean.csv
# Saved 48 entries for ped_id 171 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_171/ped_path_clean.csv
# Saved 48 entries for ped_id 172 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_172/ped_path_clean.csv
# Saved 21 entries for ped_id 284 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_284/ped_path_clean.csv
# Saved 36 entries for ped_id 173 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_173/ped_path_clean.csv
# Saved 21 entries for ped_id 430 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_430/ped_path_clean.csv
# Saved 40 entries for ped_id 286 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_286/ped_path_clean.csv
# Saved 31 entries for ped_id 174 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_174/ped_path_clean.csv
# Saved 16 entries for ped_id 431 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_431/ped_path_clean.csv
# Saved 114 entries for ped_id 362 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_362/ped_path_clean.csv
# Saved 110 entries for ped_id 363 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_363/ped_path_clean.csv
# Saved 55 entries for ped_id 432 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_432/ped_path_clean.csv
# Saved 15 entries for ped_id 175 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_175/ped_path_clean.csv
# Saved 52 entries for ped_id 364 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_364/ped_path_clean.csv
# Saved 41 entries for ped_id 176 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_176/ped_path_clean.csv
# Saved 41 entries for ped_id 177 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_177/ped_path_clean.csv
# Saved 41 entries for ped_id 178 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_178/ped_path_clean.csv
# Saved 32 entries for ped_id 287 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_287/ped_path_clean.csv
# Saved 69 entries for ped_id 179 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_179/ped_path_clean.csv
# Saved 29 entries for ped_id 180 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_180/ped_path_clean.csv
# Saved 22 entries for ped_id 288 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_288/ped_path_clean.csv
# Saved 42 entries for ped_id 181 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_181/ped_path_clean.csv
# Saved 29 entries for ped_id 182 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_182/ped_path_clean.csv
# Saved 37 entries for ped_id 183 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_183/ped_path_clean.csv
# Saved 35 entries for ped_id 184 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_184/ped_path_clean.csv
# Saved 31 entries for ped_id 185 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_185/ped_path_clean.csv
# Saved 26 entries for ped_id 186 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_186/ped_path_clean.csv
# Saved 33 entries for ped_id 187 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_187/ped_path_clean.csv
# Saved 18 entries for ped_id 188 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_188/ped_path_clean.csv
# Saved 25 entries for ped_id 417 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_417/ped_path_clean.csv
# Saved 22 entries for ped_id 418 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_418/ped_path_clean.csv
# Saved 40 entries for ped_id 189 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_189/ped_path_clean.csv
# Saved 15 entries for ped_id 365 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_365/ped_path_clean.csv
# Saved 40 entries for ped_id 190 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_190/ped_path_clean.csv
# Saved 48 entries for ped_id 191 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_191/ped_path_clean.csv
# Saved 45 entries for ped_id 192 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_192/ped_path_clean.csv
# Saved 23 entries for ped_id 194 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_194/ped_path_clean.csv
# Saved 34 entries for ped_id 366 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_366/ped_path_clean.csv
# Saved 15 entries for ped_id 400 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_400/ped_path_clean.csv
# Saved 36 entries for ped_id 263 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_263/ped_path_clean.csv
# Saved 42 entries for ped_id 193 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_193/ped_path_clean.csv
# Saved 20 entries for ped_id 195 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_195/ped_path_clean.csv
# Saved 18 entries for ped_id 367 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_367/ped_path_clean.csv
# Saved 12 entries for ped_id 368 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_368/ped_path_clean.csv
# Saved 21 entries for ped_id 196 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_196/ped_path_clean.csv
# Saved 18 entries for ped_id 197 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_197/ped_path_clean.csv
# Saved 52 entries for ped_id 198 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_198/ped_path_clean.csv
# Saved 35 entries for ped_id 200 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_200/ped_path_clean.csv
# Saved 24 entries for ped_id 401 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_401/ped_path_clean.csv
# Saved 12 entries for ped_id 199 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_199/ped_path_clean.csv
# Saved 26 entries for ped_id 402 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_402/ped_path_clean.csv
# Saved 5 entries for ped_id 289 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_289/ped_path_clean.csv
# Saved 6 entries for ped_id 290 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_290/ped_path_clean.csv
# Saved 23 entries for ped_id 201 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_201/ped_path_clean.csv
# Saved 36 entries for ped_id 291 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_291/ped_path_clean.csv
# Saved 25 entries for ped_id 202 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_202/ped_path_clean.csv
# Saved 17 entries for ped_id 433 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_433/ped_path_clean.csv
# Saved 61 entries for ped_id 204 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_204/ped_path_clean.csv
# Saved 63 entries for ped_id 203 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_203/ped_path_clean.csv
# Saved 6 entries for ped_id 369 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_369/ped_path_clean.csv
# Saved 12 entries for ped_id 370 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_370/ped_path_clean.csv
# Saved 56 entries for ped_id 205 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_205/ped_path_clean.csv
# Saved 53 entries for ped_id 206 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_206/ped_path_clean.csv
# Saved 39 entries for ped_id 371 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_371/ped_path_clean.csv
# Saved 35 entries for ped_id 264 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_264/ped_path_clean.csv
# Saved 23 entries for ped_id 207 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_207/ped_path_clean.csv
# Saved 36 entries for ped_id 265 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_265/ped_path_clean.csv
# Saved 43 entries for ped_id 266 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_266/ped_path_clean.csv
# Saved 35 entries for ped_id 208 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_208/ped_path_clean.csv
# Saved 25 entries for ped_id 210 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_210/ped_path_clean.csv
# Saved 38 entries for ped_id 267 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_267/ped_path_clean.csv
# Saved 34 entries for ped_id 209 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_209/ped_path_clean.csv
# Saved 22 entries for ped_id 211 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_211/ped_path_clean.csv
# Saved 28 entries for ped_id 337 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_337/ped_path_clean.csv
# Saved 15 entries for ped_id 212 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_212/ped_path_clean.csv
# Saved 10 entries for ped_id 403 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_403/ped_path_clean.csv
# Saved 17 entries for ped_id 374 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_374/ped_path_clean.csv
# Saved 17 entries for ped_id 372 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_372/ped_path_clean.csv
# Saved 35 entries for ped_id 434 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_434/ped_path_clean.csv
# Saved 33 entries for ped_id 292 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_292/ped_path_clean.csv
# Saved 32 entries for ped_id 269 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_269/ped_path_clean.csv
# Saved 30 entries for ped_id 268 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_268/ped_path_clean.csv
# Saved 31 entries for ped_id 270 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_270/ped_path_clean.csv
# Saved 29 entries for ped_id 293 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_293/ped_path_clean.csv
# Saved 28 entries for ped_id 294 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_294/ped_path_clean.csv
# Saved 8 entries for ped_id 373 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_373/ped_path_clean.csv
# Saved 28 entries for ped_id 271 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_271/ped_path_clean.csv
# Saved 23 entries for ped_id 295 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_295/ped_path_clean.csv
# Saved 27 entries for ped_id 375 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_375/ped_path_clean.csv
# Saved 26 entries for ped_id 296 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_296/ped_path_clean.csv
# Saved 24 entries for ped_id 297 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_297/ped_path_clean.csv
# Saved 21 entries for ped_id 404 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_404/ped_path_clean.csv
# Saved 18 entries for ped_id 405 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_405/ped_path_clean.csv
# Saved 14 entries for ped_id 338 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_338/ped_path_clean.csv
# Saved 13 entries for ped_id 406 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_406/ped_path_clean.csv
# Saved 12 entries for ped_id 272 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_272/ped_path_clean.csv
# Saved 13 entries for ped_id 339 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_339/ped_path_clean.csv
# Saved 8 entries for ped_id 407 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_407/ped_path_clean.csv
# Saved 8 entries for ped_id 298 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_298/ped_path_clean.csv
# Saved 5 entries for ped_id 299 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_299/ped_path_clean.csv
# Saved 5 entries for ped_id 408 to /home/sina/env_prediction_project/motion_predictor/ETH_datasets/U3_C_A_DIR_408/ped_path_clean.csv

# %%
desired_ped_id = 201

# Parse ground truth data
ground_truth = []
ground_truth_2 = []

# Read the CSV file with a header
with open(data_path, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ped_id = float(row["ped_id"])
        if ped_id == desired_ped_id:
            ground_truth.append([float(row["timestamp"]), ped_id, float(row["x"]), float(row["y"])])

# # Read the CSV file with a header
# with open(data_path_2, "r") as csvfile:
#     reader = csv.DictReader(csvfile)
#     for row in reader:
#         ground_truth_2.append([float(row["timestamp"]), float(row["ped_id"]), float(row["x"]), float(row["y"])])
        
gt_array = np.array(ground_truth)
# gt_array_2 = np.array(ground_truth_2)

print("Ground truth data loaded with the length: ", len(ground_truth))

# %%
# # DANGER!! INITIALIZED THE RESULTS_DF FROM THE BEGINNING

# # Make an empty dataframe to store the error values in next steps
results_df = pd.DataFrame()
# results_df = pd.read_csv("results_ours_cv_2.csv")
# results_df

# %% [markdown]
# ## Prediction Section

# %%
# Set prediction horizon
ph = 12

predictions = {}

# Group data by pedestrian ID (column 1)
pedestrian_ids = np.unique(gt_array[:, 1])

for ped_id in pedestrian_ids:
    # Filter data for the current pedestrian
    ped_data = gt_array[gt_array[:, 1] == ped_id]
    
    # Initialize predictions for this pedestrian
    ped_predictions = {}

    velocities_linear = [np.nan] * len(ped_data)
    velocities_angular = [np.nan] * len(ped_data)


    # Compute velocities
    for i in range(0, len(ped_data) - 1):
        # Linear velocity
        t0, x0, y0 = ped_data[i, 0], ped_data[i, 2], ped_data[i, 3]
        t1, x1, y1 = ped_data[i + 1, 0], ped_data[i + 1, 2], ped_data[i + 1, 3]

        dt1 = t1 - t0

        if dt1 == 0:
            print(f"Skipping due to zero time difference for pedestrian {ped_id} at index {i}")
            continue  # Avoid divide-by-zero

        vx = (x1 - x0) / dt1
        vy = (y1 - y0) / dt1

        v = np.sqrt(vx**2 + vy**2)

        velocities_linear[i + 1] = v

        # Angular velocity
        if i < len(ped_data) - 2:
            t2, x2, y2 = ped_data[i + 2, 0], ped_data[i + 2, 2], ped_data[i + 2, 3]
            dt2 = t2 - t1

            if dt2 == 0:
                print(f"Skipping omega due to zero time difference for pedestrian {ped_id} at index {i}")
                continue  # Avoid divide-by-zero
        
            theta1 = np.arctan2(y1 - y0, x1 - x0)
            theta2 = np.arctan2(y2 - y1, x2 - x1)
            dtheta = np.arctan2(np.sin(theta2 - theta1), np.cos(theta2 - theta1)) # Normalize to the range [-pi, pi]
            omega = dtheta / dt2
            velocities_angular[i + 2] = omega


   
    for i in range(0, len(ped_data) - 2 - ph): # We need 2 first steps to calculate omega, and the last ph steps cannot be a base for the prediction (no ground truth after that)


        # Gather last `avg_window` linear velocities up to i+2
        lin_window = velocities_linear[max(0, i + 2 - avg_window_lin + 1): i + 3]
        ang_window = velocities_angular[max(0, i + 2 - avg_window_ang + 1): i + 3]

        # Compute averages
        v = np.nanmean(lin_window)
        omega = np.nanmean(ang_window)

        # Skip if any required values are None
        if np.isnan(v) or np.isnan(omega):
            print(f"Skipping prediction for pedestrian {ped_id} at index {i} due to insufficient data")
            continue

        # Current base pose
        t2, x2, y2 = ped_data[i + 2, 0], ped_data[i + 2, 2], ped_data[i + 2, 3]
        dt2 = ped_data[i + 2, 0] - ped_data[i + 1, 0]

        # Compute heading for x2 (based on previous step)
        theta2 = np.arctan2(ped_data[i + 2, 3] - ped_data[i + 1, 3],
                            ped_data[i + 2, 2] - ped_data[i + 1, 2])


        ### PREDICTION PART ###

        ## Step-by-step ph-step prediction   

        next_predicted_points = []

        x_base = x2
        y_base = y2
        theta_base = theta2

        # print(x_base, y_base, theta_base)

        for j in range(ph):
            dt_s = dt2

            if abs(omega) > 1e-5:  # Non-zero turn rate
                radius = v / omega
                theta_next = theta_base + omega * dt_s
                x_next = x_base + radius * (np.sin(theta_next) - np.sin(theta_base))
                y_next = y_base - radius * (np.cos(theta_next) - np.cos(theta_base))

                # Update for next step
                theta_base = theta_next
                x_base = x_next
                y_base = y_next

            else:  # Straight-line motion
                x_next = x_base + v * np.cos(theta_base) * dt_s
                y_next = y_base + v * np.sin(theta_base) * dt_s

                # Update for next step
                x_base = x_next
                y_base = y_next

            next_predicted_points.append([x_next, y_next])


        # Time of last predicted point (not used)
        t_next = t2 + ph * dt2  # Assuming uniform timestep

        ped_predictions[t2] = next_predicted_points

    for t2 in ped_predictions:
        if t2 not in predictions:
            predictions[t2] = {}
    
        # Store the prediction
        predictions[t2][ped_id] = ped_predictions[t2]

# %% [markdown]
# ## Plot the predicted positions

# %%
# # Assuming `data_array` and `predictions` are already computed as in the previous code

# # Extract x and y limits for the plot
# x_min, x_max = np.min(data_array[:, 2]), np.max(data_array[:, 2])
# y_min, y_max = np.min(data_array[:, 3]), np.max(data_array[:, 3])

# # Create the combined plot
# plt.figure(figsize=((x_max - x_min) * 0.5, (y_max - y_min) * 0.5), dpi=300)

# # Set the x and y axis limits
plt.xlim(-100, 400)
plt.ylim(000, 500)

pedestrian_ids = np.unique(gt_array[:, 1])

# Plot ground truth trajectory (blue)
for ped_id in pedestrian_ids:
    # Filter ground truth data for the pedestrian
    ped_data = gt_array[gt_array[:, 1] == ped_id]
    x_gt, y_gt = ped_data[:, 2], ped_data[:, 3]
    
    # Plot ground truth trajectory
    plt.plot(x_gt, y_gt, marker="o", linestyle="-", markersize=3,
             label=f"Ground Truth (Ped {int(ped_id)})", linewidth=1.5)
    
    if plot_2:
        # Filter ground truth data for the pedestrian (second dataset)
        ped_data_2 = gt_array_2[gt_array_2[:, 1] == ped_id]
        x_gt_2, y_gt_2 = ped_data_2[:, 2], ped_data_2[:, 3]

        # Plot ground truth trajectory (second dataset)
        plt.plot(x_gt_2, y_gt_2, marker="*", linestyle="-", markersize=3,
            label=f"Ground Truth (Ped {int(ped_id)})", linewidth=1.5)

    ## Plot predicted trajectory

    # Connect ground truth to prediction

    for t2, ped_pred in predictions.items():
        for ped_id, pred in ped_pred.items():
            ped_data = gt_array[gt_array[:, 1] == ped_id]
            gt_timestamps = ped_data[:, 0]

            if t2 in gt_timestamps:
                idx = np.where(gt_timestamps == t2)[0][0]
                x_start = ped_data[idx, 2]
                y_start = ped_data[idx, 3]

                color = np.random.rand(3,)

                for point in pred:
                    x_pred, y_pred = point
                    plt.plot([x_start, x_pred], [y_start, y_pred],
                         color=color, linestyle='dotted',
                         marker="x", markersize=4)
                    
                    x_start, y_start = x_pred, y_pred
                    # break


    ## THESE PLOTS ARE NOT WORKING ANYMORE
    # plt.plot(p_x, p_y, marker="x", linewidth=1, linestyle='--', label='Predicted Positions', color="red") # Connect all prediction to each other, only useful for one-step prediction
    # plt.scatter(p_x, p_y, marker="x", label='Predicted Positions', color="red") # Just show the predicted positions

# Mark start and end positions
for ped_id in np.unique(gt_array[:, 1]):
    ped_data = gt_array[gt_array[:, 1] == ped_id]
    x_gt, y_gt = ped_data[:, 2], ped_data[:, 3]
    plt.scatter(x_gt[0], y_gt[0], color="green", s=25, label=f"Start Position (Ped {int(ped_id)})")
    plt.scatter(x_gt[-1], y_gt[-1], color="blue", s=25, label=f"End Position (Ped {int(ped_id)})")
#     plt.scatter()
#     [40.77488327026367, 253.8969268798828],
#  [0.4355576923076923, 1.0, 62.06704711914063, 248.269775390625],
#  [0.51475, 1.0, 71.64285278320312, 234.6148834228516],
    
# plt.gca().invert_yaxis()  # Invert Y to match video coordinates
# plt.gca().invert_xaxis()  # Invert X to match video coordinates

# Titles and labels
plt.title(f"{pred_model} Predictions on {file_name}")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
plt.close()

# %%
error_fde = []
error_fde_normal = []

error_ade = []
error_ade_normal = []

i = 0
for t2, ped_dict in predictions.items():
    for ped_id, pred_list in ped_dict.items():
        # Skip empty predictions
        if len(pred_list) < 1:
            continue


        # Get corresponding ground truth for ped_id
        ped_data = gt_array[gt_array[:, 1] == ped_id]
        gt_timestamps = ped_data[:, 0]


        if t2 not in gt_timestamps:
            print("Unexpected problem! The prediction base timestep is not present in ground truth!")
            continue

        start_idx = np.where(gt_timestamps == t2)[0][0]
        target_idx = start_idx + ph


        if target_idx >= len(ped_data):
            print('Not enough GT data to evaluate')
            continue

        # --- FDE ---

        # Get the last predicted point (FDE)
        pred_fde = np.array(pred_list[-1])
        gt_fde = np.array([ped_data[target_idx, 2], ped_data[target_idx, 3]])
        dist_fde = np.linalg.norm(pred_fde - gt_fde)
        error_fde.append(dist_fde)

        # Normalized error over ground truth path (t2 to t_target)
        steps_size_fde = 0

        for j in range(1, ph + 1):
            if start_idx + j >= len(ped_data):
                break
            step_start = np.array([ped_data[start_idx + j - 1, 2], ped_data[start_idx + j - 1, 3]])
            step_end = np.array([ped_data[start_idx + j, 2], ped_data[start_idx + j, 3]])
            step_size = np.linalg.norm(step_end - step_start)
            if not np.isnan(step_size):
                steps_size_fde += step_size

        if steps_size_fde > 0:
            error_fde_normal.append(dist_fde / steps_size_fde)
        else:
            error_fde_normal.append(np.nan)

        # --- ADE ---

        total_dist = 0
        total_dist_normalized = 0
        valid_steps = 0
        valid_points = 0

        for j in range(ph):
            if start_idx + j + 1 >= len(ped_data) or j >= len(pred_list):
                break

            pred_step = np.array(pred_list[j])
            gt_step = np.array([ped_data[start_idx + j + 1, 2], ped_data[start_idx + j + 1, 3]])
            dist_step = np.linalg.norm(pred_step - gt_step)

            if not np.isnan(dist_step):
                total_dist += dist_step
                valid_points += 1

            # Normalize by step size between GT positions
            step_start = np.array([ped_data[start_idx + j, 2], ped_data[start_idx + j, 3]])
            step_end = np.array([ped_data[start_idx + j + 1, 2], ped_data[start_idx + j + 1, 3]])
            step_size = np.linalg.norm(step_end - step_start)

            if not np.isnan(step_size):
                total_dist_normalized += dist_step / step_size
                valid_steps += 1


        if valid_steps > 0:
            error_ade_normal.append(total_dist_normalized / valid_steps)
        else:
            error_ade_normal.append(np.nan)
                

        if valid_points > 0:
            error_ade.append(total_dist / valid_points)
        else:
            error_ade.append(np.nan)


        i += 1

# Compute and print averages
fde_avg = np.nanmean(error_fde)
ade_avg = np.nanmean(error_ade)
print('Final displacement error (FDE): {:.3f}'.format(fde_avg))
print('Average displacement error (ADE): {:.3f}'.format(ade_avg))

fde_avg_normal = np.nanmean(error_fde_normal)
ade_avg_normal = np.nanmean(error_ade_normal)
print('Normalized FDE: {:.3f}'.format(fde_avg_normal))
print('ADE Normalized: {:.3f}'.format(ade_avg_normal))
# Out:
# Final displacement error (FDE): 212.435
# Average displacement error (ADE): 161.985
# Normalized FDE: 0.547
# ADE Normalized: 6.253

# %%
avg_window_lin = 8
avg_window_ang = 8

ph = 12

## Directories for datasets
base_dirs = [
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Straight Line/Vertical Line",
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Straight Line/Horizontal Line",
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Straight Line/Diagonal Line",
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Infinity Loop",
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Square Path",
    "/home/sina/env_prediction_project/trajectory_detection/Recorded Datasets/Circular Path"
]

# base_dirs = [
#     "/home/sina/env_prediction_project/motion_predictor/ETH_datasets"
# ]

results = []


def parse_value(val):
    if val is None:
        return np.nan
    val = val.strip().lower()
    return float(val) if val not in ('', 'none', 'nan') else np.nan


for base_dir in base_dirs:
    for root, dirs, files in os.walk(base_dir):

        dataset_name = root.split("/")[-1]
        if dataset_name.startswith('x_'):
            continue

        for file in files:

            if not file.endswith("_raw.csv"):
                continue

            # if ph == 4 and file.endswith("_2.5hz_clean.csv"):
            #     continue
            
            data_path = os.path.join(root, file)

            # Load data and calculate prediction error
            try:
                # Parse ground truth data
                ground_truth = []

                # Read the CSV file with a header
                with open(data_path, "r") as csvfile:
                    reader = csv.DictReader(csvfile)
                    for row in reader:
                        ground_truth.append([
                            float(row["timestamp"]),
                            float(row["ped_id"]),
                            parse_value(row["x"]),
                            parse_value(row["y"])
                            ])
                        
                gt_array = np.array(ground_truth)

                # Group data by pedestrian ID (column 1)
                pedestrian_ids = np.unique(gt_array[:, 1])

                predictions = {}

                for ped_id in pedestrian_ids:
                    # Filter data for the current pedestrian
                    ped_data = gt_array[gt_array[:, 1] == ped_id]
                    
                    # Initialize predictions for this pedestrian
                    ped_predictions = {}

                    velocities_linear = [np.nan] * len(ped_data)
                    velocities_angular = [np.nan] * len(ped_data)

                    # Compute velocities
                    for i in range(len(ped_data) - 1):
                        # Linear velocity
                        t0, x0, y0 = ped_data[i, 0], ped_data[i, 2], ped_data[i, 3]
                        t1, x1, y1 = ped_data[i + 1, 0], ped_data[i + 1, 2], ped_data[i + 1, 3]

                        dt1 = t1 - t0

                        if dt1 == 0:
                            print(f"Skipping due to zero time difference for pedestrian {ped_id} at index {i}")
                            continue # Avoid divide-by-zero

                        vx = (x1 - x0) / dt1
                        vy = (y1 - y0) / dt1

                        v = np.sqrt(vx**2 + vy**2)

                        velocities_linear[i + 1] = v

                        # Angular velocity
                        if i < len(ped_data) - 2:
                            t2, x2, y2 = ped_data[i + 2, 0], ped_data[i + 2, 2], ped_data[i + 2, 3]
                            dt2 = t2 - t1

                            if dt2 == 0:
                                print(f"Skipping omega due to zero time difference for pedestrian {ped_id} at index {i}")
                                continue  # Avoid divide-by-zero

                            theta1 = np.arctan2(y1 - y0, x1 - x0)
                            theta2 = np.arctan2(y2 - y1, x2 - x1)
                            dtheta = np.arctan2(np.sin(theta2 - theta1), np.cos(theta2 - theta1)) # Normalize to the range [-pi, pi]
                            omega = dtheta / dt2
                            velocities_angular[i + 2] = omega

                    
                    for i in range(0, len(ped_data) - 2 - ph):

                        # Gather last `avg_window` linear velocities up to i+2
                        lin_window = velocities_linear[max(0, i + 2 - avg_window_lin + 1): i + 3]
                        ang_window = velocities_angular[max(0, i + 2 - avg_window_ang + 1): i + 3]

                        # Compute averages
                        v = np.nanmean(lin_window)
                        omega = np.nanmean(ang_window)

                        # Skip if any required values are None
                        if np.isnan(v) or np.isnan(omega):
                            print(f"{dataset_name} No velocity found. Skipping prediction for pedestrian {ped_id} at index {i} due to insufficient data")
                            continue

                        # Current base pose
                        t2, x2, y2 = ped_data[i + 2, 0], ped_data[i + 2, 2], ped_data[i + 2, 3]
                        dt2 = ped_data[i + 2, 0] - ped_data[i + 1, 0]

                        theta2 = np.arctan2(ped_data[i + 2, 3] - ped_data[i + 1, 3],
                                            ped_data[i + 2, 2] - ped_data[i + 1, 2])


                        ### PREDICTION PART ###

                        ## Step-by-step ph-step prediction
                        
                        next_predicted_points = []  

                        x_base = x2
                        y_base = y2
                        theta_base = theta2 

                        for j in range(ph):
                            dt_s = dt2

                            if abs(omega) > 1e-5:  # Non-zero turn rate
                                radius = v / omega
                                theta_next = theta_base + omega * dt_s
                                x_next = x_base + radius * (np.sin(theta_next) - np.sin(theta_base))
                                y_next = y_base - radius * (np.cos(theta_next) - np.cos(theta_base))

                                # Update for next step
                                theta_base = theta_next
                                x_base = x_next
                                y_base = y_next

                            else:
                                x_next = x_base + v * np.cos(theta_base) * dt_s
                                y_next = y_base + v * np.sin(theta_base) * dt_s

                                # Update for next step
                                x_base = x_next
                                y_base = y_next
                                
                            next_predicted_points.append([x_next, y_next])

                        #  Time of last predicted point (not used)
                        t_next = t2 + ph * dt2 # Assuming uniform timestep
            
                        # Store the prediction
                        ped_predictions[t2] = next_predicted_points
                        
                    for t2 in ped_predictions:
                        if t2 not in predictions:
                            predictions[t2] = {}
                    
                        # Store the prediction
                        predictions[t2][ped_id] = ped_predictions[t2]

       
                error_fde = []
                error_fde_normal = []

                error_ade = []
                error_ade_normal = []

                i = 0
                for t2, ped_dict in predictions.items():
                    for ped_id, pred_list in ped_dict.items():
                        # Skip empty predictions
                        if len(pred_list) < 1:
                            continue

                        # Get corresponding ground truth for ped_id
                        ped_data = gt_array[gt_array[:, 1] == ped_id]
                        gt_timestamps = ped_data[:, 0]


                        if t2 not in gt_timestamps:
                            print("Unexpected ERROR! The prediction base timestep is not present in ground truth")
                            continue


                        start_idx = np.where(gt_timestamps == t2)[0][0]
                        target_idx = start_idx + ph

                        if target_idx >= len(ped_data):
                            print('Not enough GT data to evaluate')
                            continue

                        # --- FDE ---

                        # Get the last predicted point (FDE)
                        pred_fde = np.array(pred_list[-1])
                        gt_fde = np.array([ped_data[target_idx, 2], ped_data[target_idx, 3]])
                        dist_fde = np.linalg.norm(pred_fde - gt_fde)
                        error_fde.append(dist_fde)

                        # Normalized error over ground truth path (t2 to t_target)
                        steps_size_fde = 0

                        for j in range(1, ph + 1):
                            if start_idx + j >= len(ped_data):
                                break
                            step_start = np.array([ped_data[start_idx + j - 1, 2], ped_data[start_idx + j - 1, 3]])
                            step_end = np.array([ped_data[start_idx + j, 2], ped_data[start_idx + j, 3]])
                            step_size = np.linalg.norm(step_end - step_start)
                            if not np.isnan(step_size):
                                steps_size_fde += step_size


                        if steps_size_fde > 0:
                            error_fde_normal.append(dist_fde / steps_size_fde)
                        else:
                            error_fde_normal.append(np.nan)


                        # --- ADE ---
                        
                        total_dist = 0
                        total_dist_normalized = 0
                        valid_steps = 0
                        valid_points = 0

                        for j in range(ph):
                            if start_idx + j + 1 >= len(ped_data) or j >= len(pred_list):
                                break

                            pred_step = np.array(pred_list[j])
                            gt_step = np.array([ped_data[start_idx + j + 1, 2], ped_data[start_idx + j + 1, 3]])
                            dist_step = np.linalg.norm(pred_step - gt_step)

                            if not np.isnan(dist_step):
                                total_dist += dist_step
                                valid_points += 1

                            # Normalize by step size between GT positions
                            step_start = np.array([ped_data[start_idx + j, 2], ped_data[start_idx + j, 3]])
                            step_end = np.array([ped_data[start_idx + j + 1, 2], ped_data[start_idx + j + 1, 3]])
                            step_size = np.linalg.norm(step_end - step_start)

                            if not np.isnan(step_size):
                                total_dist_normalized += dist_step / step_size
                                valid_steps += 1


                        if valid_steps > 0:
                            error_ade_normal.append(total_dist_normalized / valid_steps)
                        else:
                            error_ade_normal.append(np.nan)
                                

                        if valid_points > 0:
                            error_ade.append(total_dist / valid_points)
                        else:
                            error_ade.append(np.nan)


                        i += 1
                                    
                fde_avg = np.nanmean(error_fde)
                ade_avg = np.nanmean(error_ade)

                fde_avg_normal = np.nanmean(error_fde_normal)
                ade_avg_normal = np.nanmean(error_ade_normal)


                # Append result
                results.append({
                    "Dataset Name": dataset_name,
                    "Path Type": dataset_name[:4],
                    "Acceleration Type": dataset_name.split("_")[2],
                    "Path Direction": dataset_name.split("_")[3],
                    "Path Number": dataset_name.split("_")[4],
                    "Sample Rate": file.split("_")[-2],
                    "Prediction Horizon": ph,
                    "Prediction Model": pred_model,
                    "Angular Avg. Window": avg_window_ang,
                    "Linear Avg. Window": avg_window_lin,
                    "Average ADE": ade_avg,
                    "Average ADE (Normalized)": ade_avg_normal,
                    "Average FDE": fde_avg,
                    "Average FDE (Normalized)": fde_avg_normal
                })

                # print(f"Processed {file_name} with {data_file}: Average Error = {ade_avg}")
            except Exception as e:
                print(f"Error processing {dataset_name} with {file}: {e}")


results_df = pd.concat([results_df, pd.DataFrame(results)]).drop_duplicates(keep='last').reset_index(drop=True)
# Out:
# /tmp/ipykernel_8795/3534584831.py:286: RuntimeWarning: Mean of empty slice
#   fde_avg = np.nanmean(error_fde)
# /tmp/ipykernel_8795/3534584831.py:287: RuntimeWarning: Mean of empty slice
#   ade_avg = np.nanmean(error_ade)
# /tmp/ipykernel_8795/3534584831.py:289: RuntimeWarning: Mean of empty slice
#   fde_avg_normal = np.nanmean(error_fde_normal)
# /tmp/ipykernel_8795/3534584831.py:290: RuntimeWarning: Mean of empty slice
#   ade_avg_normal = np.nanmean(error_ade_normal)
# /tmp/ipykernel_8795/3534584831.py:122: RuntimeWarning: Mean of empty slice
#   v = np.nanmean(lin_window)
# /tmp/ipykernel_8795/3534584831.py:123: RuntimeWarning: Mean of empty slice
#   omega = np.nanmean(ang_window)
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 68 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 69 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 70 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 71 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 72 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 73 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 74 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 75 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 76 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 77 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 78 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 79 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 80 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 81 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 82 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 83 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 84 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 85 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 86 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 87 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 88 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 89 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 90 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 91 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 92 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 93 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 94 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 95 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 96 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 97 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 98 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 99 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 100 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 101 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 102 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 103 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 104 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 105 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 106 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 107 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 108 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 109 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 110 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 111 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 112 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 113 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 114 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 30 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 31 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 32 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 33 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 34 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 35 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 36 due to insufficient data
# VL_C_F_TD_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 37 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 18 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 19 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 20 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 21 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 22 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 23 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 24 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 25 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 26 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 27 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 28 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 29 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 30 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 31 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 32 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 33 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 34 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 35 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 36 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 37 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 38 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 39 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 40 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 41 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 42 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 43 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_F_BU_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 18 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 19 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_BU_6 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 18 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 19 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 20 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 21 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 22 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 23 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 24 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 25 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 26 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 27 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 28 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 29 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 30 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 31 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 32 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 33 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 34 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 35 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 36 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 37 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 38 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 39 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 40 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 85 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 86 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 87 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 88 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 89 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 90 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_F_TD_5 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 56 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 57 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 58 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 59 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 60 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 61 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 62 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 63 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 64 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 65 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 66 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 67 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 68 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 69 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 70 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 71 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 72 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 73 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 74 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 75 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 76 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 77 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 78 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 79 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 80 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 81 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 82 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 83 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 84 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 85 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 86 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 87 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 88 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 89 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 90 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 91 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 92 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 93 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 94 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 95 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 96 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 97 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 98 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 99 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 100 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 101 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 102 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 103 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 104 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 105 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 106 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 107 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 108 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 109 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 110 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 111 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 112 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 113 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 114 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 26 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 27 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 28 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 29 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 30 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 31 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 32 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 33 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 34 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 35 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 36 due to insufficient data
# VL_C_A_TD_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 37 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 18 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 19 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 20 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 21 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_A_BU_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 13 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 14 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 15 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 16 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 17 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 18 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 19 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 20 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 21 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 22 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 23 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 24 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 25 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# VL_C_A_BU_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 54 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 55 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 56 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 57 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 58 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 59 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 60 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 61 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 62 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 63 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 64 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 65 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 66 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 67 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 68 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 69 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 70 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 71 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 72 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 73 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 74 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 75 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 76 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 77 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 78 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 79 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 80 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 81 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 82 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 83 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 84 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 85 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 86 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 87 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 88 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 89 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 90 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 91 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 92 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 93 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 94 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 95 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 96 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 97 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 98 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 99 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 100 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 101 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 102 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 103 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 104 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 105 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 106 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 107 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 108 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 109 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 110 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 111 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 112 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 113 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 114 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 115 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 116 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 117 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 118 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 119 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 120 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 121 due to insufficient data
# VL_C_F_TD_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 122 due to insufficient data
# ...
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 27 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 28 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# SP_C_A_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 242 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 243 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 244 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 245 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 246 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 247 due to insufficient data
# SP_C_A_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 248 due to insufficient data
# SP_C_F_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 34 due to insufficient data
# SP_C_F_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 119 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 201 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 202 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 203 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 204 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 219 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_A_CW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 9 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 10 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 11 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 12 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# SP_C_F_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 164 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 165 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 166 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 167 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 168 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 169 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 170 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 171 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 172 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 173 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 174 due to insufficient data
# SP_C_A_CCW_2 No velocity found. Skipping prediction for pedestrian 1.0 at index 175 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 195 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 196 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 197 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 198 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 199 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 200 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 201 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 202 due to insufficient data
# SP_C_A_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 203 due to insufficient data
# SP_C_F_CCW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 217 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_A_CW_3 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CCW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 213 due to insufficient data
# SP_C_F_CCW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 214 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 6 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 7 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 8 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_4 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 3 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 4 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 5 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 21 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 22 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 23 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 24 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 25 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 0 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 1 due to insufficient data
# SP_C_F_CW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 2 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 42 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 43 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 169 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 170 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 171 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 172 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 173 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 174 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 175 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 176 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 177 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 178 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 249 due to insufficient data
# SP_C_F_CCW_1 No velocity found. Skipping prediction for pedestrian 1.0 at index 71 due to insufficient data

# %%
# Remove duplicate rows based on all columns and keep the last occurrence
# results_df = pd.concat([results_df, pd.DataFrame(results)]).drop_duplicates(keep='last').reset_index(drop=True)
# df_filtered = results_df[results_df['data_file'].str.endswith('2.5hz_clean.csv')]
# Replace all values in the 'Sample Rate' column with 2.5
# results_df['Sample Rate'] = 2.5
# Display the DataFrame
results_df
# df_filtered
# Out:
#      Dataset Name Path Type Acceleration Type Path Direction Path Number  \
# 0     VL_C_F_TD_3      VL_C                 F             TD           3
# 1     VL_C_F_TD_3      VL_C                 F             TD           3
# 2     VL_C_F_TD_3      VL_C                 F             TD           3
# 3     VL_C_F_BU_5      VL_C                 F             BU           5
# 4     VL_C_F_BU_5      VL_C                 F             BU           5
# ..            ...       ...               ...            ...         ...
# 301  CP_C_F_CCW_3      CP_C                 F            CCW           3
# 302  CP_C_F_CCW_3      CP_C                 F            CCW           3
# 303   CP_C_A_CW_1      CP_C                 A             CW           1
# 304   CP_C_A_CW_1      CP_C                 A             CW           1
# 305   CP_C_A_CW_1      CP_C                 A             CW           1
#
#     Sample Rate  Prediction Horizon Prediction Model  Angular Avg. Window  \
# 0         2.5hz                  12             CTRV                    8
# 1          full                  12             CTRV                    8
# 2          10hz                  12             CTRV                    8
# 3         2.5hz                  12             CTRV                    8
# 4          full                  12             CTRV                    8
# ..          ...                 ...              ...                  ...
# 301        full                  12             CTRV                    8
# 302        10hz                  12             CTRV                    8
# 303       2.5hz                  12             CTRV                    8
# 304        full                  12             CTRV                    8
# 305        10hz                  12             CTRV                    8
#
#      Linear Avg. Window  Average ADE  Average ADE (Normalized)  Average FDE  \
# 0                     8          NaN                       NaN          NaN
# 1                     8    29.553700                 14.758202    51.308765
# 2                     8    43.735014                  8.752607   121.633231
# 3                     8          NaN                       NaN          NaN
# 4                     8    32.264864                  7.887493    53.593246
# ..                  ...          ...                       ...          ...
# 301                   8    33.048667                  8.782961    59.436916
# 302                   8    60.037920                  9.265627    99.289739
# 303                   8          NaN                       NaN          NaN
# 304                   8    32.711598                  9.514688    58.759517
# 305                   8    66.556742                  8.201789   121.461452
#
#      Average FDE (Normalized)
# 0                         NaN
# 1                    0.867913
# 2                    0.913104
# 3                         NaN
# 4                    0.812423
# ..                        ...
# 301                  0.952413
# 302                  0.725296
# 303                       NaN
# 304                  0.852958
# 305                  0.759241
#
# [306 rows x 14 columns]

# %%
results_df.to_csv("results_ours_CTRV_with_None.csv", index=False)

# %%
results_df_filtered = results_df[
    # (results_df['Prediction Model'] == 'CV')
    (results_df['Sample Rate'] == '2.5hz') &
    (results_df['Dataset Name'].isin(['IL_C_A_RCCW_1']))
    # # (results_df['Prediction Horizon'] == 4) &
    # (results_df['Acceleration Type'] == 'F') &
    # (results_df['Path Type'] == 'DL_C')
    ]

results_df_filtered
# results_df.groupby([
#     'path_type',
#     # 'acceleration_type',
#     'sample_rate'
#                     ]).agg({'average_error': ['mean', 'std'],
#     'average_error_normal': ['mean', 'std']}).reset_index()
# Out:
#       Dataset Name Path Type Acceleration Type Path Direction Path Number  \
# 198  IL_C_A_RCCW_1      IL_C                 A           RCCW           1
#
#     Sample Rate  Prediction Horizon Prediction Model  Angular Avg. Window  \
# 198       2.5hz                  12             CTRV                    8
#
#      Linear Avg. Window  Average ADE  Average ADE (Normalized)  Average FDE  \
# 198                   8   161.985302                  6.253372   212.435144
#
#      Average FDE (Normalized)
# 198                  0.546981
